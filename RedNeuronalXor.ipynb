# %% [markdown]
# En este ejercicio vamos a resolver el resultado de la compuerta Xor con 2 neuronas, basicamente esto es un perceptron, primero voy a programar tradicionalmente y despúes implementare las redes neuronales.

# %% [markdown]
# La funcion XOr me tiene que dar como resultado lo siguiente:
#
#
# ![xor.jpg](data:image/jpeg;base64,...)

# %%
def my_function(entrada1, entrada2):
    if(entrada1 != entrada2):
       return print(1)
    else: 
       return print(0)

# %% [markdown]
# vamos a llamar a la funcion para corroborar la logica que se implemento este trabajando correctamente:

# %%
var1 = my_function(0, 0)
var2 = my_function(0, 1)
var3 = my_function(1, 0)
var4 = my_function(1, 1)

var1
var2
var3
var4
# Out:
# 0
# 1
# 1
# 0

# %% [markdown]
# **Ahora con redes neuronales resolvemos el problema de arriba:**
#
# ![xor.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense
 
# cargamos las 4 combinaciones de las compuertas XOR
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")
 
# y estos son los resultados que se obtienen, en el mismo orden
target_data = np.array([[0],[1],[1],[0]], "float32")
 
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
 
model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['binary_accuracy'])


print(training_data)
print(target_data)
 
model.fit(training_data, target_data, epochs=1000)
 
# evaluamos el modelo
scores = model.evaluate(training_data, target_data)
 
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print (model.predict(training_data).round())

print (model.predict(np.array([[0,0],[1,1]], "float32")).round())
# Out:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Epoch 1/1000
# 1/1 [==============================] - 1s 676ms/step - loss: 0.2256 - binary_accuracy: 0.7500
# Epoch 2/1000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2252 - binary_accuracy: 0.5000
# Epoch 3/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2247 - binary_accuracy: 0.5000
# Epoch 4/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2243 - binary_accuracy: 0.7500
# Epoch 5/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2239 - binary_accuracy: 0.7500
# Epoch 6/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2235 - binary_accuracy: 0.7500
# Epoch 7/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2230 - binary_accuracy: 0.7500
# Epoch 8/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2226 - binary_accuracy: 0.7500
# Epoch 9/1000
# ...

# %%
print (model.predict(np.array([[0,1],[1,0],[0,0],[1,1]], "float32")).round())
# Out:
# [[1.]
#  [1.]
#  [0.]
#  [0.]]

# %% [markdown]
# Vamos a probrar si la red neuronal responde correctamente a todos los escenarios el primero en evaluar es 0,1

# %%
print (model.predict(np.array([[0,1]], "float32")).round())
# Out:
# [[1.]]

# %% [markdown]
# Vamos a probrar si la red neuronal responde correctamente a todos los escenarios el segundo en evaluar es 1,0

# %%
print (model.predict(np.array([[1,0]], "float32")).round())
# Out:
# [[1.]]

# %% [markdown]
# Vamos a probrar si la red neuronal responde correctamente a todos los escenarios el tercer ecenario en evaluar es 1,1

# %%
print (model.predict(np.array([[1,1]], "float32")).round())
# Out:
# [[0.]]

# %% [markdown]
# Vamos a probrar si la red neuronal responde correctamente a todos los escenarios el tercer ecenario en evaluar es 0,0

# %%
print (model.predict(np.array([[0,0]], "float32")).round())
# Out:
# [[0.]]
